# %%
import pandas as pd
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error, mean_squared_error

# %%
df = pd.read_csv("insurance.csv")  # replace w/ path
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
# Columns often: age, sex, bmi, children, smoker, region, charges
df_encoded = pd.get_dummies(df, drop_first=True)
X = df_encoded.drop('charges', axis=1)
y = df_encoded['charges']

# %%
import numpy as np
from sklearn.metrics import mean_absolute_error, mean_squared_error

# Evaluate
mae = mean_absolute_error(y_test, y_pred)
rmse = np.sqrt(mean_squared_error(y_test, y_pred))  # use sqrt manually

print("MAE:", mae)
print("RMSE:", rmse)
# Out:
# MAE: 4181.1944737536505
# RMSE: 5796.284659276272

# %%
# Imports
import matplotlib.pyplot as plt
import seaborn as sns

# Scatter plot: BMI vs Charges by smoker status
plt.figure(figsize=(6,4))
sns.scatterplot(x=df['bmi'], y=df['charges'], hue=df['smoker'])
plt.title('BMI vs Charges colored by Smoker')
plt.show()

# Regression plot: Age vs Charges
plt.figure(figsize=(6,4))
sns.regplot(x='age', y='charges', data=df, lowess=True)
plt.title('Age vs Charges')
plt.show()
